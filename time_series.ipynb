# %% [markdown]
# ## Time Series Analysics

# %%
import pandas as pd 
import numpy as np 

from numpy.random import randn

from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import seaborn as sns

from pylab import rcParams

# %%
# %matplotlib inline
sns.set_style('whitegrid')
rcParams['figure.figsize'] = 8,4

# %%
## The simples time series plot

# %%
address = r'C:/Users/sharvan.das/Desktop/Python Data Science/DataSets/train.csv'

# %%
df = pd.read_csv(address)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df_train = pd.read_csv(address, index_col= 'Order Date', parse_dates = True)

# %%
df_train.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 08/11/2017       1  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 08/11/2017       2  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 12/06/2017       3  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 11/10/2016       4  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 11/10/2016       5  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 08/11/2017      Claire Gute   Consumer  United States        Henderson
# 08/11/2017      Claire Gute   Consumer  United States        Henderson
# 12/06/2017  Darrin Van Huff  Corporate  United States      Los Angeles
# 11/10/2016   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 11/10/2016   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
df_train.columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales'],
#       dtype='object')

# %%
address_2 = r'C:/Users/sharvan.das/Desktop/Python Data Science/DataSets/sales_data_sample.csv'

# %%
df_1 = pd.read_csv(address_2, index_col= 'ORDERDATE', encoding='cp1252', parse_dates= True)

# %%
df_1.head()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
#
#              STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  \
# ORDERDATE                                                    ...
# 2003-02-24  Shipped       1         2     2003  Motorcycles  ...
# 2003-05-07  Shipped       2         5     2003  Motorcycles  ...
# 2003-07-01  Shipped       3         7     2003  Motorcycles  ...
# 2003-08-25  Shipped       3         8     2003  Motorcycles  ...
# 2003-10-10  Shipped       4        10     2003  Motorcycles  ...
#
# ...

# %%
df_1['QUANTITYORDERED'].plot()
# Out:
# <Axes: xlabel='ORDERDATE'>

# %%
df_2 = df_1.sample(n = 10, random_state=42, axis=0)
plt.xlabel('Order Date')
plt.ylabel('Order Quantity')
plt.title('Random Date Super Store Sales')
df_2['QUANTITYORDERED'].plot()
# Out:
# <Axes: title={'center': 'Random Date Super Store Sales'}, xlabel='ORDERDATE', ylabel='Order Quantity'>

# %%
## Statistical Plots

# %%
# Histogram
# Scatter Plot
# Box Plot
